# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io, exposure
from skimage.color import rgb2gray
from skimage import filters
from scipy import ndimage as ndi
import skimage
from skimage.morphology import square
from skimage.morphology import binary_erosion
from scipy.spatial import distance
import math

#środek ciężkości
def cog2(points):
    mx=0
    my=0
    for (y,x) in points:
        mx = mx + x
        my = my + y
    mx = mx/len(points)
    my = my/len(points)
    mx = round(mx, 2)
    my = round(my, 2)
    
    return [my, mx]


def getFigure(labelledImage, objNumber):
    
    points = []
    for y in range(labelledImage.shape[0]):
        for x in range(labelledImage.shape[1]):
            if labelledImage[y,x] == objNumber:
                points.append((y,x))

    return points

def computeBB(points):
    
    s = len(points)
    my,mx = cog2(pts)
    
    r = 0
    for point in points:
         r = r + distance.euclidean(point,(my,mx))**2
            
    return s/(math.sqrt(2*math.pi*r))


def computeFeret(points):
    
    px = [x for (y,x) in points]
    py = [y for (y,x) in points]
    
    fx = max(px) - min(px)
    fy = max(py) - min(py)
    
    return float(fy)/float(fx) 


path = 'zdjecia/'
for z in range(1, 19):
                        #Wczytywanie zdjec, przerabianie ich na skale szarosci
    image = io.imread(path + 'z{}.jpg'.format(z))
    image = rgb2gray(image)

   # plt.imshow(image, cmap='gray')
   # plt.axis('on')
   # plt.suptitle('Analizowany obraz')
   # plt.show()
    
                                    #----Histogram
    #print('Histogram')
   # hist, bins = exposure.histogram(image)
    #print(hist.shape, hist.dtype)
    #plt.figure()
   # plt.plot(hist, color="black")
   # plt.show()
    
                                    #----Binaryzacja
    #print('Obraz po binaryzacji')
    th = filters.threshold_otsu(image)
    erosion = binary = image > th
  
   # plt.imshow(binary, cmap='binary')
   # plt.axis('on')
   # plt.show()
    
                                    #----Erozja
   # print("Po erozji")

    square = np.array([[1, 1, 1],
                       [1, 1, 1], 
                       [1, 1, 1]], dtype=np.uint8)
    
    for i in range(5):
        erosion = binary_erosion(erosion, square)
    
   # plt.imshow(erosion, cmap="gray")
   # plt.axis('off')
   # plt.show()
    
                                    #---Wyliczanie obiektow na obrazie
    #print('Obiekty na obrazie')
    label_objects, nb_labels = ndi.label(erosion)
    
    #plt.imshow(label_objects, cmap="hot")
    #plt.axis('on')
    #plt.show()
    
    
    values, counts = np.unique(binary, return_counts=True)
    T=counts[1]
    F=counts[0]
    full = (T/(T+F))*100
    full = round(full, 2)
    
    print("Ilosc obiektów na zdjęciu {}: ".format(z) + str(nb_labels))  
    print("Obiekty zajmuja: {}".format(full) +"% obszaru zdjęcia")

    for i in range(nb_labels):
        pts = getFigure(label_objects, i+1)
        bb = computeBB(pts)
        bb = round(bb, 4)
        feret = computeFeret(pts)
        feret = round(feret, 4)
        
        print('Srodek ciezkosci: ', cog2(pts))
        print('Współczynnik Blair-Bliss\'a: ', bb)
        print('Współczynnik Feret\'a: ',feret)
        print('\n')
    print('\n\n')
# Out:
# Ilosc obiektów na zdjęciu 1: 7
# Obiekty zajmuja: 3.42% obszaru zdjęcia
# Srodek ciezkosci:  [104.93, 226.32]
# Współczynnik Blair-Bliss'a:  0.9912
# Współczynnik Feret'a:  1.0588
#
#
# Srodek ciezkosci:  [104.74, 266.65]
# Współczynnik Blair-Bliss'a:  0.9966
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [131.56, 352.17]
# Współczynnik Blair-Bliss'a:  0.9956
# Współczynnik Feret'a:  0.8947
#
#
# Srodek ciezkosci:  [132.73, 218.06]
# Współczynnik Blair-Bliss'a:  0.9951
# Współczynnik Feret'a:  0.9444
#
#
# Srodek ciezkosci:  [158.02, 274.55]
# Współczynnik Blair-Bliss'a:  0.9969
# Współczynnik Feret'a:  0.9412
#
#
# Srodek ciezkosci:  [187.03, 230.64]
# Współczynnik Blair-Bliss'a:  0.9949
# Współczynnik Feret'a:  1.0588
#
#
# Srodek ciezkosci:  [205.94, 295.86]
# Współczynnik Blair-Bliss'a:  0.9933
# Współczynnik Feret'a:  1.0
#
#
#
#
#
# Ilosc obiektów na zdjęciu 2: 9
# Obiekty zajmuja: 4.4% obszaru zdjęcia
# Srodek ciezkosci:  [73.63, 210.19]
# Współczynnik Blair-Bliss'a:  0.9898
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [78.27, 238.93]
# Współczynnik Blair-Bliss'a:  0.9938
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [101.1, 219.72]
# Współczynnik Blair-Bliss'a:  0.9907
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [116.51, 285.2]
# Współczynnik Blair-Bliss'a:  0.996
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [147.08, 242.07]
# Współczynnik Blair-Bliss'a:  0.9955
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [170.9, 299.28]
# Współczynnik Blair-Bliss'a:  0.9925
# Współczynnik Feret'a:  1.0588
#
#
# Srodek ciezkosci:  [175.23, 166.86]
# Współczynnik Blair-Bliss'a:  0.9963
# Współczynnik Feret'a:  0.9444
#
#
# Srodek ciezkosci:  [198.85, 291.82]
# Współczynnik Blair-Bliss'a:  0.9935
# Współczynnik Feret'a:  1.1176
#
#
# Srodek ciezkosci:  [199.67, 251.67]
# Współczynnik Blair-Bliss'a:  0.9966
# Współczynnik Feret'a:  1.0
#
#
#
#
#
# Ilosc obiektów na zdjęciu 3: 4
# Obiekty zajmuja: 2.2% obszaru zdjęcia
# Srodek ciezkosci:  [83.87, 280.04]
# Współczynnik Blair-Bliss'a:  0.9962
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [147.05, 269.03]
# Współczynnik Blair-Bliss'a:  0.9975
# Współczynnik Feret'a:  0.95
#
#
# Srodek ciezkosci:  [189.38, 284.63]
# Współczynnik Blair-Bliss'a:  0.9962
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [236.49, 277.01]
# Współczynnik Blair-Bliss'a:  0.9963
# Współczynnik Feret'a:  1.0556
#
#
#
#
#
# Ilosc obiektów na zdjęciu 4: 8
# Obiekty zajmuja: 4.76% obszaru zdjęcia
# Srodek ciezkosci:  [65.99, 297.78]
# Współczynnik Blair-Bliss'a:  0.9956
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [109.03, 243.0]
# Współczynnik Blair-Bliss'a:  0.9976
# Współczynnik Feret'a:  1.05
#
#
# Srodek ciezkosci:  [131.78, 285.41]
# Współczynnik Blair-Bliss'a:  0.9966
# Współczynnik Feret'a:  0.9524
#
#
# Srodek ciezkosci:  [158.88, 206.69]
# Współczynnik Blair-Bliss'a:  0.9966
# Współczynnik Feret'a:  0.9524
#
#
# Srodek ciezkosci:  [177.48, 300.79]
# Współczynnik Blair-Bliss'a:  0.9917
# Współczynnik Feret'a:  1.05
#
#
# Srodek ciezkosci:  [204.97, 287.07]
# Współczynnik Blair-Bliss'a:  0.9925
# Współczynnik Feret'a:  1.05
#
#
# Srodek ciezkosci:  [223.55, 200.95]
# Współczynnik Blair-Bliss'a:  0.9956
# Współczynnik Feret'a:  1.05
#
#
# Srodek ciezkosci:  [251.77, 228.98]
# Współczynnik Blair-Bliss'a:  0.996
# Współczynnik Feret'a:  1.05
#
#
#
#
#
# Ilosc obiektów na zdjęciu 5: 8
# Obiekty zajmuja: 4.58% obszaru zdjęcia
# Srodek ciezkosci:  [63.97, 309.97]
# Współczynnik Blair-Bliss'a:  0.9956
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [107.25, 256.07]
# Współczynnik Blair-Bliss'a:  0.9951
# Współczynnik Feret'a:  1.05
#
#
# Srodek ciezkosci:  [137.3, 267.94]
# Współczynnik Blair-Bliss'a:  0.9928
# Współczynnik Feret'a:  1.05
#
#
# Srodek ciezkosci:  [157.82, 220.42]
# Współczynnik Blair-Bliss'a:  0.9974
# Współczynnik Feret'a:  1.0526
#
#
# Srodek ciezkosci:  [169.0, 277.01]
# Współczynnik Blair-Bliss'a:  0.988
# Współczynnik Feret'a:  1.05
#
#
# Srodek ciezkosci:  [195.9, 291.02]
# Współczynnik Blair-Bliss'a:  0.9898
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [221.83, 215.56]
# Współczynnik Blair-Bliss'a:  0.9971
# Współczynnik Feret'a:  1.0526
#
#
# Srodek ciezkosci:  [249.3, 243.62]
# Współczynnik Blair-Bliss'a:  0.9956
# Współczynnik Feret'a:  1.1053
#
#
#
#
#
# Ilosc obiektów na zdjęciu 6: 19
# Obiekty zajmuja: 8.06% obszaru zdjęcia
# Srodek ciezkosci:  [83.59, 180.72]
# Współczynnik Blair-Bliss'a:  0.9933
# Współczynnik Feret'a:  0.9375
#
#
# Srodek ciezkosci:  [84.27, 347.15]
# Współczynnik Blair-Bliss'a:  0.9944
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [106.29, 165.36]
# Współczynnik Blair-Bliss'a:  0.9938
# Współczynnik Feret'a:  0.9375
#
#
# Srodek ciezkosci:  [109.1, 240.9]
# Współczynnik Blair-Bliss'a:  0.9948
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [116.35, 212.51]
# Współczynnik Blair-Bliss'a:  0.9927
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [120.89, 301.5]
# Współczynnik Blair-Bliss'a:  0.989
# Współczynnik Feret'a:  1.0667
#
#
# Srodek ciezkosci:  [146.29, 312.0]
# Współczynnik Blair-Bliss'a:  0.9915
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [151.07, 230.29]
# Współczynnik Blair-Bliss'a:  0.9953
# Współczynnik Feret'a:  0.9333
#
#
# Srodek ciezkosci:  [153.97, 127.33]
# Współczynnik Blair-Bliss'a:  0.9916
# Współczynnik Feret'a:  0.9412
#
#
# Srodek ciezkosci:  [155.01, 170.21]
# Współczynnik Blair-Bliss'a:  0.9943
# Współczynnik Feret'a:  0.9375
#
#
# Srodek ciezkosci:  [168.71, 260.33]
# Współczynnik Blair-Bliss'a:  0.9938
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [173.77, 320.48]
# Współczynnik Blair-Bliss'a:  0.9828
# Współczynnik Feret'a:  1.0667
#
#
# Srodek ciezkosci:  [182.41, 171.76]
# Współczynnik Blair-Bliss'a:  0.9919
# Współczynnik Feret'a:  0.9375
#
#
# Srodek ciezkosci:  [186.75, 232.15]
# Współczynnik Blair-Bliss'a:  0.9963
# Współczynnik Feret'a:  1.0714
#
#
# Srodek ciezkosci:  [187.98, 110.9]
# Współczynnik Blair-Bliss'a:  0.9921
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [197.0, 333.07]
# Współczynnik Blair-Bliss'a:  0.9797
# Współczynnik Feret'a:  1.0667
#
#
# Srodek ciezkosci:  [206.52, 208.49]
# Współczynnik Blair-Bliss'a:  0.9945
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [211.19, 267.12]
# Współczynnik Blair-Bliss'a:  0.9972
# Współczynnik Feret'a:  1.0714
#
#
# Srodek ciezkosci:  [243.46, 292.52]
# Współczynnik Blair-Bliss'a:  0.9936
# Współczynnik Feret'a:  1.0
#
#
#
#
#
# Ilosc obiektów na zdjęciu 7: 16
# Obiekty zajmuja: 6.82% obszaru zdjęcia
# Srodek ciezkosci:  [83.33, 337.04]
# Współczynnik Blair-Bliss'a:  0.9944
# Współczynnik Feret'a:  0.9375
#
#
# Srodek ciezkosci:  [108.11, 230.69]
# Współczynnik Blair-Bliss'a:  0.9965
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [116.75, 203.65]
# Współczynnik Blair-Bliss'a:  0.9952
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [119.89, 291.35]
# Współczynnik Blair-Bliss'a:  0.9921
# Współczynnik Feret'a:  1.0667
#
#
# Srodek ciezkosci:  [145.65, 302.13]
# Współczynnik Blair-Bliss'a:  0.9954
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [152.96, 117.15]
# Współczynnik Blair-Bliss'a:  0.9945
# Współczynnik Feret'a:  0.9412
#
#
# Srodek ciezkosci:  [154.2, 159.9]
# Współczynnik Blair-Bliss'a:  0.9934
# Współczynnik Feret'a:  0.9375
#
#
# Srodek ciezkosci:  [168.13, 250.25]
# Współczynnik Blair-Bliss'a:  0.9955
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [173.22, 310.75]
# Współczynnik Blair-Bliss'a:  0.9873
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [181.72, 161.34]
# Współczynnik Blair-Bliss'a:  0.9921
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [186.25, 221.92]
# Współczynnik Blair-Bliss'a:  0.9962
# Współczynnik Feret'a:  1.0714
#
#
# Srodek ciezkosci:  [187.17, 100.49]
# Współczynnik Blair-Bliss'a:  0.9927
# Współczynnik Feret'a:  0.8824
#
#
# Srodek ciezkosci:  [197.08, 323.47]
# Współczynnik Blair-Bliss'a:  0.9849
# Współczynnik Feret'a:  1.0667
#
#
# Srodek ciezkosci:  [206.35, 198.14]
# Współczynnik Blair-Bliss'a:  0.9943
# Współczynnik Feret'a:  0.9375
#
#
# Srodek ciezkosci:  [211.05, 257.03]
# Współczynnik Blair-Bliss'a:  0.9948
# Współczynnik Feret'a:  1.1429
#
#
# Srodek ciezkosci:  [243.97, 282.47]
# Współczynnik Blair-Bliss'a:  0.9926
# Współczynnik Feret'a:  1.0667
#
#
#
#
#
# Ilosc obiektów na zdjęciu 8: 16
# Obiekty zajmuja: 8.02% obszaru zdjęcia
# Srodek ciezkosci:  [78.05, 180.05]
# Współczynnik Blair-Bliss'a:  0.9959
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [89.99, 326.83]
# Współczynnik Blair-Bliss'a:  0.996
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [109.54, 257.38]
# Współczynnik Blair-Bliss'a:  0.9977
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [119.0, 226.72]
# Współczynnik Blair-Bliss'a:  0.9948
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [128.3, 282.28]
# Współczynnik Blair-Bliss'a:  0.9962
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [139.14, 187.0]
# Współczynnik Blair-Bliss'a:  0.9957
# Współczynnik Feret'a:  1.0
# Srodek ciezkosci:  [158.01, 292.91]
# Współczynnik Blair-Bliss'a:  0.9969
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [170.89, 174.51]
# Współczynnik Blair-Bliss'a:  0.9938
# Współczynnik Feret'a:  0.9474
#
#
# Srodek ciezkosci:  [186.5, 238.64]
# Współczynnik Blair-Bliss'a:  0.9981
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [188.2, 304.27]
# Współczynnik Blair-Bliss'a:  0.9868
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [191.59, 150.16]
# Współczynnik Blair-Bliss'a:  0.9936
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [206.78, 210.08]
# Współczynnik Blair-Bliss'a:  0.9961
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [212.86, 319.6]
# Współczynnik Blair-Bliss'a:  0.9862
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [220.36, 247.91]
# Współczynnik Blair-Bliss'a:  0.9915
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [232.11, 184.26]
# Współczynnik Blair-Bliss'a:  0.9926
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [232.27, 274.99]
# Współczynnik Blair-Bliss'a:  0.9922
# Współczynnik Feret'a:  1.0
#
#
#
#
#
# Ilosc obiektów na zdjęciu 9: 16
# Obiekty zajmuja: 6.26% obszaru zdjęcia
# Srodek ciezkosci:  [101.93, 306.18]
# Współczynnik Blair-Bliss'a:  0.9969
# Współczynnik Feret'a:  0.9333
#
#
# Srodek ciezkosci:  [107.55, 174.53]
# Współczynnik Blair-Bliss'a:  0.9941
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [127.3, 246.64]
# Współczynnik Blair-Bliss'a:  0.9858
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [142.92, 223.68]
# Współczynnik Blair-Bliss'a:  0.996
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [147.0, 263.62]
# Współczynnik Blair-Bliss'a:  0.9779
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [164.97, 206.61]
# Współczynnik Blair-Bliss'a:  0.9953
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [168.14, 278.04]
# Współczynnik Blair-Bliss'a:  0.9808
# Współczynnik Feret'a:  1.0769
#
#
# Srodek ciezkosci:  [186.9, 186.84]
# Współczynnik Blair-Bliss'a:  0.9944
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [189.37, 234.73]
# Współczynnik Blair-Bliss'a:  0.9954
# Współczynnik Feret'a:  1.0769
#
#
# Srodek ciezkosci:  [190.56, 295.94]
# Współczynnik Blair-Bliss'a:  0.9792
# Współczynnik Feret'a:  1.0769
#
#
# Srodek ciezkosci:  [208.59, 168.59]
# Współczynnik Blair-Bliss'a:  0.9936
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [209.66, 311.23]
# Współczynnik Blair-Bliss'a:  0.9825
# Współczynnik Feret'a:  1.0769
#
#
# Srodek ciezkosci:  [232.79, 220.97]
# Współczynnik Blair-Bliss'a:  0.9952
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [236.76, 195.07]
# Współczynnik Blair-Bliss'a:  0.9931
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [236.92, 246.54]
# Współczynnik Blair-Bliss'a:  0.9957
# Współczynnik Feret'a:  1.0769
#
#
# Srodek ciezkosci:  [237.32, 272.74]
# Współczynnik Blair-Bliss'a:  0.9939
# Współczynnik Feret'a:  1.0
#
#
#
#
#
# Ilosc obiektów na zdjęciu 10: 16
# Obiekty zajmuja: 6.95% obszaru zdjęcia
# Srodek ciezkosci:  [38.29, 260.13]
# Współczynnik Blair-Bliss'a:  0.9949
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [57.3, 280.65]
# Współczynnik Blair-Bliss'a:  0.9947
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [70.55, 183.3]
# Współczynnik Blair-Bliss'a:  0.9925
# Współczynnik Feret'a:  0.9375
#
#
# Srodek ciezkosci:  [75.83, 248.18]
# Współczynnik Blair-Bliss'a:  0.9933
# Współczynnik Feret'a:  1.1429
#
#
# Srodek ciezkosci:  [94.31, 268.39]
# Współczynnik Blair-Bliss'a:  0.9935
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [102.25, 242.15]
# Współczynnik Blair-Bliss'a:  0.9916
# Współczynnik Feret'a:  1.0667
#
#
# Srodek ciezkosci:  [101.92, 357.31]
# Współczynnik Blair-Bliss'a:  0.994
# Współczynnik Feret'a:  1.0667
#
#
# Srodek ciezkosci:  [129.89, 190.44]
# Współczynnik Blair-Bliss'a:  0.9948
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [137.9, 320.72]
# Współczynnik Blair-Bliss'a:  0.9957
# Współczynnik Feret'a:  0.9375
#
#
# Srodek ciezkosci:  [157.02, 295.7]
# Współczynnik Blair-Bliss'a:  0.9947
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [162.54, 203.01]
# Współczynnik Blair-Bliss'a:  0.9952
# Współczynnik Feret'a:  0.9375
#
#
# Srodek ciezkosci:  [191.8, 250.86]
# Współczynnik Blair-Bliss'a:  0.9912
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [193.51, 216.94]
# Współczynnik Blair-Bliss'a:  0.995
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [200.45, 284.31]
# Współczynnik Blair-Bliss'a:  0.9931
# Współczynnik Feret'a:  1.0667
#
#
# Srodek ciezkosci:  [217.55, 262.31]
# Współczynnik Blair-Bliss'a:  0.9892
# Współczynnik Feret'a:  1.0625
#
#
# Srodek ciezkosci:  [220.3, 202.99]
# Współczynnik Blair-Bliss'a:  0.9942
# Współczynnik Feret'a:  1.0625
#
#
#
#
#
# Ilosc obiektów na zdjęciu 11: 28
# Obiekty zajmuja: 8.91% obszaru zdjęcia
# Srodek ciezkosci:  [40.0, 248.35]
# Współczynnik Blair-Bliss'a:  0.9955
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [44.68, 181.04]
# Współczynnik Blair-Bliss'a:  0.9919
# Współczynnik Feret'a:  1.0833
#
#
# Srodek ciezkosci:  [71.11, 181.32]
# Współczynnik Blair-Bliss'a:  0.9931
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [71.76, 249.77]
# Współczynnik Blair-Bliss'a:  0.9945
# Współczynnik Feret'a:  1.0909
#
#
# Srodek ciezkosci:  [77.46, 333.2]
# Współczynnik Blair-Bliss'a:  0.9913
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [83.12, 158.13]
# Współczynnik Blair-Bliss'a:  0.9772
# Współczynnik Feret'a:  0.9231
#
#
# Srodek ciezkosci:  [98.4, 176.43]
# Współczynnik Blair-Bliss'a:  0.9865
# Współczynnik Feret'a:  0.9167
#
#
# Srodek ciezkosci:  [100.13, 320.43]
# Współczynnik Blair-Bliss'a:  0.9919
# Współczynnik Feret'a:  1.0909
#
#
# Srodek ciezkosci:  [101.07, 291.07]
# Współczynnik Blair-Bliss'a:  0.9946
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [126.54, 331.57]
# Współczynnik Blair-Bliss'a:  0.9969
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [129.05, 135.42]
# Współczynnik Blair-Bliss'a:  0.9927
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [130.0, 252.5]
# Współczynnik Blair-Bliss'a:  0.9978
# Współczynnik Feret'a:  0.9091
#
#
# Srodek ciezkosci:  [143.44, 231.13]
# Współczynnik Blair-Bliss'a:  0.9965
# Współczynnik Feret'a:  1.1
#
#
# Srodek ciezkosci:  [152.34, 140.88]
# Współczynnik Blair-Bliss'a:  0.9912
# Współczynnik Feret'a:  0.9167
#
#
# Srodek ciezkosci:  [154.41, 341.48]
# Współczynnik Blair-Bliss'a:  0.9972
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [173.97, 191.69]
# Współczynnik Blair-Bliss'a:  0.9955
# Współczynnik Feret'a:  0.9091
#
#
# Srodek ciezkosci:  [177.0, 296.62]
# Współczynnik Blair-Bliss'a:  0.9919
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [183.57, 274.36]
# Współczynnik Blair-Bliss'a:  0.9839
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [199.18, 290.87]
# Współczynnik Blair-Bliss'a:  0.9803
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [201.58, 128.29]
# Współczynnik Blair-Bliss'a:  0.9846
# Współczynnik Feret'a:  0.9167
#
#
# Srodek ciezkosci:  [204.61, 346.18]
# Współczynnik Blair-Bliss'a:  0.9923
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [205.5, 244.5]
# Współczynnik Blair-Bliss'a:  0.9897
# Współczynnik Feret'a:  1.2222
#
#
# Srodek ciezkosci:  [212.16, 181.71]
# Współczynnik Blair-Bliss'a:  0.9916
# Współczynnik Feret'a:  0.9091
#
#
# Srodek ciezkosci:  [226.08, 274.36]
# Współczynnik Blair-Bliss'a:  0.9982
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [230.43, 202.87]
# Współczynnik Blair-Bliss'a:  0.9948
# Współczynnik Feret'a:  1.1
#
#
# Srodek ciezkosci:  [235.14, 160.65]
# Współczynnik Blair-Bliss'a:  0.9894
# Współczynnik Feret'a:  0.9091
#
#
# Srodek ciezkosci:  [247.32, 232.98]
# Współczynnik Blair-Bliss'a:  0.9938
# Współczynnik Feret'a:  1.1
#
#
# Srodek ciezkosci:  [263.37, 207.43]
# Współczynnik Blair-Bliss'a:  0.9928
# Współczynnik Feret'a:  1.0
#
#
#
#
#
# Ilosc obiektów na zdjęciu 12: 28
# Obiekty zajmuja: 8.89% obszaru zdjęcia
# Srodek ciezkosci:  [51.62, 247.05]
# Współczynnik Blair-Bliss'a:  0.9935
# Współczynnik Feret'a:  1.0833
#
#
# Srodek ciezkosci:  [87.71, 333.41]
# Współczynnik Blair-Bliss'a:  0.9851
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [87.82, 250.32]
# Współczynnik Blair-Bliss'a:  0.9866
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [90.24, 275.54]
# Współczynnik Blair-Bliss'a:  0.984
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [98.65, 228.82]
# Współczynnik Blair-Bliss'a:  0.9877
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [106.04, 292.22]
# Współczynnik Blair-Bliss'a:  0.9834
# Współczynnik Feret'a:  0.9167
#
#
# Srodek ciezkosci:  [109.48, 321.47]
# Współczynnik Blair-Bliss'a:  0.9857
# Współczynnik Feret'a:  1.0833
#
#
# Srodek ciezkosci:  [114.74, 256.67]
# Współczynnik Blair-Bliss'a:  0.9942
# Współczynnik Feret'a:  1.0
# Srodek ciezkosci:  [123.07, 227.87]
# Współczynnik Blair-Bliss'a:  0.9963
# Współczynnik Feret'a:  1.0909
#
#
# Srodek ciezkosci:  [134.17, 195.46]
# Współczynnik Blair-Bliss'a:  0.9916
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [136.17, 333.85]
# Współczynnik Blair-Bliss'a:  0.9937
# Współczynnik Feret'a:  0.9167
#
#
# Srodek ciezkosci:  [138.21, 274.79]
# Współczynnik Blair-Bliss'a:  0.9961
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [146.84, 230.32]
# Współczynnik Blair-Bliss'a:  0.9946
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [157.0, 201.57]
# Współczynnik Blair-Bliss'a:  0.9916
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [157.67, 314.24]
# Współczynnik Blair-Bliss'a:  0.9939
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [160.6, 338.08]
# Współczynnik Blair-Bliss'a:  0.9914
# Współczynnik Feret'a:  0.9167
#
#
# Srodek ciezkosci:  [173.06, 292.85]
# Współczynnik Blair-Bliss'a:  0.9744
# Współczynnik Feret'a:  1.0909
#
#
# Srodek ciezkosci:  [185.75, 194.47]
# Współczynnik Blair-Bliss'a:  0.9903
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [191.57, 280.23]
# Współczynnik Blair-Bliss'a:  0.9754
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [195.39, 256.12]
# Współczynnik Blair-Bliss'a:  0.9928
# Współczynnik Feret'a:  1.1
#
#
# Srodek ciezkosci:  [207.56, 295.43]
# Współczynnik Blair-Bliss'a:  0.9711
# Współczynnik Feret'a:  1.2
#
#
# Srodek ciezkosci:  [218.03, 251.26]
# Współczynnik Blair-Bliss'a:  0.9812
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [225.38, 184.17]
# Współczynnik Blair-Bliss'a:  0.9581
# Współczynnik Feret'a:  1.0909
#
#
# Srodek ciezkosci:  [234.97, 236.79]
# Współczynnik Blair-Bliss'a:  0.9781
# Współczynnik Feret'a:  1.1
#
#
# Srodek ciezkosci:  [236.77, 207.16]
# Współczynnik Blair-Bliss'a:  0.9916
# Współczynnik Feret'a:  1.1
#
#
# Srodek ciezkosci:  [237.09, 277.86]
# Współczynnik Blair-Bliss'a:  0.9981
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [240.4, 169.78]
# Współczynnik Blair-Bliss'a:  0.9559
# Współczynnik Feret'a:  1.0909
#
#
# Srodek ciezkosci:  [262.78, 172.67]
# Współczynnik Blair-Bliss'a:  0.9864
# Współczynnik Feret'a:  1.1
#
#
#
#
#
# Ilosc obiektów na zdjęciu 13: 27
# Obiekty zajmuja: 11.03% obszaru zdjęcia
# Srodek ciezkosci:  [91.19, 250.67]
# Współczynnik Blair-Bliss'a:  0.9872
# Współczynnik Feret'a:  1.0667
#
#
# Srodek ciezkosci:  [113.99, 235.66]
# Współczynnik Blair-Bliss'a:  0.9772
# Współczynnik Feret'a:  1.0667
#
#
# Srodek ciezkosci:  [115.46, 263.96]
# Współczynnik Blair-Bliss'a:  0.9816
# Współczynnik Feret'a:  1.0667
#
#
# Srodek ciezkosci:  [136.7, 220.84]
# Współczynnik Blair-Bliss'a:  0.9656
# Współczynnik Feret'a:  1.2143
#
#
# Srodek ciezkosci:  [138.61, 249.7]
# Współczynnik Blair-Bliss'a:  0.9766
# Współczynnik Feret'a:  1.0667
#
#
# Srodek ciezkosci:  [140.65, 276.92]
# Współczynnik Blair-Bliss'a:  0.98
# Współczynnik Feret'a:  1.1429
#
#
# Srodek ciezkosci:  [159.46, 207.67]
# Współczynnik Blair-Bliss'a:  0.9703
# Współczynnik Feret'a:  1.0667
#
#
# Srodek ciezkosci:  [160.33, 234.69]
# Współczynnik Blair-Bliss'a:  0.9717
# Współczynnik Feret'a:  1.0667
#
#
# Srodek ciezkosci:  [162.72, 262.84]
# Współczynnik Blair-Bliss'a:  0.973
# Współczynnik Feret'a:  1.2143
#
#
# Srodek ciezkosci:  [163.07, 289.66]
# Współczynnik Blair-Bliss'a:  0.978
# Współczynnik Feret'a:  1.1429
#
#
# Srodek ciezkosci:  [181.49, 194.21]
# Współczynnik Blair-Bliss'a:  0.9619
# Współczynnik Feret'a:  1.1429
#
#
# Srodek ciezkosci:  [182.36, 220.96]
# Współczynnik Blair-Bliss'a:  0.9579
# Współczynnik Feret'a:  1.2143
#
#
# Srodek ciezkosci:  [184.35, 248.52]
# Współczynnik Blair-Bliss'a:  0.9674
# Współczynnik Feret'a:  1.1429
#
#
# Srodek ciezkosci:  [185.07, 274.83]
# Współczynnik Blair-Bliss'a:  0.9715
# Współczynnik Feret'a:  1.1429
#
#
# Srodek ciezkosci:  [186.4, 301.51]
# Współczynnik Blair-Bliss'a:  0.9811
# Współczynnik Feret'a:  1.0714
#
#
# Srodek ciezkosci:  [212.85, 175.02]
# Współczynnik Blair-Bliss'a:  0.5969
# Współczynnik Feret'a:  1.2857
#
#
# Srodek ciezkosci:  [204.05, 207.97]
# Współczynnik Blair-Bliss'a:  0.9628
# Współczynnik Feret'a:  1.1429
#
#
# Srodek ciezkosci:  [206.49, 234.84]
# Współczynnik Blair-Bliss'a:  0.9696
# Współczynnik Feret'a:  1.1429
#
#
# Srodek ciezkosci:  [206.71, 261.05]
# Współczynnik Blair-Bliss'a:  0.9616
# Współczynnik Feret'a:  1.1429
#
#
# Srodek ciezkosci:  [209.4, 287.27]
# Współczynnik Blair-Bliss'a:  0.9765
# Współczynnik Feret'a:  1.0714
#
#
# Srodek ciezkosci:  [212.03, 315.34]
# Współczynnik Blair-Bliss'a:  0.9878
# Współczynnik Feret'a:  1.0714
#
#
# Srodek ciezkosci:  [224.47, 194.29]
# Współczynnik Blair-Bliss'a:  0.9869
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [227.5, 221.37]
# Współczynnik Blair-Bliss'a:  0.9784
# Współczynnik Feret'a:  1.0714
#
#
# Srodek ciezkosci:  [226.72, 247.39]
# Współczynnik Blair-Bliss'a:  0.9849
# Współczynnik Feret'a:  1.0714
#
#
# Srodek ciezkosci:  [230.58, 275.07]
# Współczynnik Blair-Bliss'a:  0.9778
# Współczynnik Feret'a:  1.0714
#
#
# Srodek ciezkosci:  [233.64, 300.79]
# Współczynnik Blair-Bliss'a:  0.9909
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [234.82, 326.72]
# Współczynnik Blair-Bliss'a:  0.9836
# Współczynnik Feret'a:  1.0714
#
#
#
#
#
# Ilosc obiektów na zdjęciu 14: 24
# Obiekty zajmuja: 7.56% obszaru zdjęcia
# Srodek ciezkosci:  [78.51, 260.94]
# Współczynnik Blair-Bliss'a:  0.9946
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [83.24, 168.3]
# Współczynnik Blair-Bliss'a:  0.9948
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [86.77, 331.4]
# Współczynnik Blair-Bliss'a:  0.9918
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [103.15, 254.5]
# Współczynnik Blair-Bliss'a:  0.9913
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [131.0, 244.0]
# Współczynnik Blair-Bliss'a:  0.9947
# Współczynnik Feret'a:  1.2
#
#
# Srodek ciezkosci:  [164.2, 255.59]
# Współczynnik Blair-Bliss'a:  0.9865
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [185.37, 264.13]
# Współczynnik Blair-Bliss'a:  0.9845
# Współczynnik Feret'a:  1.0909
#
#
# Srodek ciezkosci:  [191.74, 214.28]
# Współczynnik Blair-Bliss'a:  0.9889
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [196.61, 310.9]
# Współczynnik Blair-Bliss'a:  0.9896
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [199.86, 141.38]
# Współczynnik Blair-Bliss'a:  0.9902
# Współczynnik Feret'a:  0.9167
#
#
# Srodek ciezkosci:  [210.68, 290.33]
# Współczynnik Blair-Bliss'a:  0.9838
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [211.42, 230.95]
# Współczynnik Blair-Bliss'a:  0.9836
# Współczynnik Feret'a:  0.9091
#
#
# Srodek ciezkosci:  [211.49, 357.11]
# Współczynnik Blair-Bliss'a:  0.9936
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [217.48, 155.61]
# Współczynnik Blair-Bliss'a:  0.979
# Współczynnik Feret'a:  0.9167
#
#
# Srodek ciezkosci:  [223.58, 272.49]
# Współczynnik Blair-Bliss'a:  0.9848
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [225.07, 248.24]
# Współczynnik Blair-Bliss'a:  0.9817
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [228.57, 176.26]
# Współczynnik Blair-Bliss'a:  0.977
# Współczynnik Feret'a:  0.8462
#
#
# Srodek ciezkosci:  [231.5, 340.48]
# Współczynnik Blair-Bliss'a:  0.9871
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [237.96, 197.89]
# Współczynnik Blair-Bliss'a:  0.9793
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [243.47, 220.83]
# Współczynnik Blair-Bliss'a:  0.993
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [245.81, 295.21]
# Współczynnik Blair-Bliss'a:  0.9959
# Współczynnik Feret'a:  1.1
#
#
# Srodek ciezkosci:  [246.05, 318.9]
# Współczynnik Blair-Bliss'a:  0.9892
# Współczynnik Feret'a:  1.2
#
#
# Srodek ciezkosci:  [247.32, 244.0]
# Współczynnik Blair-Bliss'a:  0.9826
# Współczynnik Feret'a:  1.2
#
#
# Srodek ciezkosci:  [248.67, 272.25]
# Współczynnik Blair-Bliss'a:  0.9962
# Współczynnik Feret'a:  1.1
#
#
#
#
#
# Ilosc obiektów na zdjęciu 15: 24
# Obiekty zajmuja: 6.3% obszaru zdjęcia
# Srodek ciezkosci:  [60.67, 155.26]
# Współczynnik Blair-Bliss'a:  0.9835
# Współczynnik Feret'a:  0.9091
#
#
# Srodek ciezkosci:  [67.68, 336.02]
# Współczynnik Blair-Bliss'a:  0.9889
# Współczynnik Feret'a:  1.1
#
#
# Srodek ciezkosci:  [109.13, 240.13]
# Współczynnik Blair-Bliss'a:  0.9889
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [131.0, 234.0]
# Współczynnik Blair-Bliss'a:  0.9972
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [155.73, 224.87]
# Współczynnik Blair-Bliss'a:  0.9767
# Współczynnik Feret'a:  0.9
#
#
# Srodek ciezkosci:  [158.91, 264.91]
# Współczynnik Blair-Bliss'a:  0.9962
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [165.38, 243.38]
# Współczynnik Blair-Bliss'a:  0.9818
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [196.66, 123.96]
# Współczynnik Blair-Bliss'a:  0.9491
# Współczynnik Feret'a:  0.8182
# Srodek ciezkosci:  [204.86, 324.65]
# Współczynnik Blair-Bliss'a:  0.9499
# Współczynnik Feret'a:  0.9
#
#
# Srodek ciezkosci:  [208.65, 106.46]
# Współczynnik Blair-Bliss'a:  0.9145
# Współczynnik Feret'a:  0.75
#
#
# Srodek ciezkosci:  [214.41, 342.75]
# Współczynnik Blair-Bliss'a:  0.9149
# Współczynnik Feret'a:  0.8182
#
#
# Srodek ciezkosci:  [218.92, 126.37]
# Współczynnik Blair-Bliss'a:  0.9726
# Współczynnik Feret'a:  0.9
#
#
# Srodek ciezkosci:  [219.06, 89.88]
# Współczynnik Blair-Bliss'a:  0.9477
# Współczynnik Feret'a:  0.8182
#
#
# Srodek ciezkosci:  [226.13, 359.63]
# Współczynnik Blair-Bliss'a:  0.956
# Współczynnik Feret'a:  0.8889
#
#
# Srodek ciezkosci:  [227.91, 325.39]
# Współczynnik Blair-Bliss'a:  0.9902
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [231.78, 143.54]
# Współczynnik Blair-Bliss'a:  0.9655
# Współczynnik Feret'a:  0.9
#
#
# Srodek ciezkosci:  [241.58, 162.75]
# Współczynnik Blair-Bliss'a:  0.9544
# Współczynnik Feret'a:  0.8182
#
#
# Srodek ciezkosci:  [245.72, 310.52]
# Współczynnik Blair-Bliss'a:  0.9869
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [249.95, 182.3]
# Współczynnik Blair-Bliss'a:  0.9777
# Współczynnik Feret'a:  0.8
#
#
# Srodek ciezkosci:  [254.93, 202.89]
# Współczynnik Blair-Bliss'a:  0.9882
# Współczynnik Feret'a:  0.8889
#
#
# Srodek ciezkosci:  [257.62, 270.1]
# Współczynnik Blair-Bliss'a:  0.9858
# Współczynnik Feret'a:  1.125
#
#
# Srodek ciezkosci:  [258.61, 223.73]
# Współczynnik Blair-Bliss'a:  0.9889
# Współczynnik Feret'a:  1.125
#
#
# Srodek ciezkosci:  [258.33, 291.24]
# Współczynnik Blair-Bliss'a:  0.9973
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [259.93, 249.17]
# Współczynnik Blair-Bliss'a:  0.9967
# Współczynnik Feret'a:  1.0
#
#
#
#
#
# Ilosc obiektów na zdjęciu 16: 17
# Obiekty zajmuja: 7.79% obszaru zdjęcia
# Srodek ciezkosci:  [77.38, 251.94]
# Współczynnik Blair-Bliss'a:  0.9927
# Współczynnik Feret'a:  1.0625
#
#
# Srodek ciezkosci:  [82.23, 337.7]
# Współczynnik Blair-Bliss'a:  0.9959
# Współczynnik Feret'a:  1.0588
#
#
# Srodek ciezkosci:  [82.44, 184.23]
# Współczynnik Blair-Bliss'a:  0.9897
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [88.86, 221.04]
# Współczynnik Blair-Bliss'a:  0.9851
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [104.71, 243.01]
# Współczynnik Blair-Bliss'a:  0.9819
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [107.09, 200.34]
# Współczynnik Blair-Bliss'a:  0.9866
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [108.11, 280.92]
# Współczynnik Blair-Bliss'a:  0.9956
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [123.15, 222.44]
# Współczynnik Blair-Bliss'a:  0.977
# Współczynnik Feret'a:  0.9412
#
#
# Srodek ciezkosci:  [128.79, 259.81]
# Współczynnik Blair-Bliss'a:  0.9924
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [136.45, 321.69]
# Współczynnik Blair-Bliss'a:  0.9945
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [149.32, 234.88]
# Współczynnik Blair-Bliss'a:  0.9811
# Współczynnik Feret'a:  1.125
#
#
# Srodek ciezkosci:  [173.18, 221.63]
# Współczynnik Blair-Bliss'a:  0.9879
# Współczynnik Feret'a:  1.0625
#
#
# Srodek ciezkosci:  [173.23, 249.46]
# Współczynnik Blair-Bliss'a:  0.9897
# Współczynnik Feret'a:  1.0625
#
#
# Srodek ciezkosci:  [181.86, 305.06]
# Współczynnik Blair-Bliss'a:  0.9925
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [205.96, 289.39]
# Współczynnik Blair-Bliss'a:  0.9907
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [220.49, 263.39]
# Współczynnik Blair-Bliss'a:  0.9876
# Współczynnik Feret'a:  1.125
#
#
# Srodek ciezkosci:  [247.45, 274.75]
# Współczynnik Blair-Bliss'a:  0.9877
# Współczynnik Feret'a:  1.1176
#
#
#
#
#
# Ilosc obiektów na zdjęciu 17: 16
# Obiekty zajmuja: 9.2% obszaru zdjęcia
# Srodek ciezkosci:  [47.03, 262.02]
# Współczynnik Blair-Bliss'a:  0.9915
# Współczynnik Feret'a:  1.1667
#
#
# Srodek ciezkosci:  [51.68, 356.13]
# Współczynnik Blair-Bliss'a:  0.9946
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [53.1, 189.96]
# Współczynnik Blair-Bliss'a:  0.9842
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [77.05, 252.95]
# Współczynnik Blair-Bliss'a:  0.983
# Współczynnik Feret'a:  1.1111
#
#
# Srodek ciezkosci:  [78.65, 206.5]
# Współczynnik Blair-Bliss'a:  0.983
# Współczynnik Feret'a:  1.0556
#
#
# Srodek ciezkosci:  [80.64, 293.03]
# Współczynnik Blair-Bliss'a:  0.9971
# Współczynnik Feret'a:  0.95
#
#
# Srodek ciezkosci:  [96.61, 229.74]
# Współczynnik Blair-Bliss'a:  0.9757
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [102.62, 269.72]
# Współczynnik Blair-Bliss'a:  0.9904
# Współczynnik Feret'a:  1.1111
#
#
# Srodek ciezkosci:  [111.1, 337.15]
# Współczynnik Blair-Bliss'a:  0.9968
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [124.29, 242.77]
# Współczynnik Blair-Bliss'a:  0.9862
# Współczynnik Feret'a:  1.1111
#
#
# Srodek ciezkosci:  [126.26, 160.34]
# Współczynnik Blair-Bliss'a:  0.9962
# Współczynnik Feret'a:  0.9474
#
#
# Srodek ciezkosci:  [152.07, 244.77]
# Współczynnik Blair-Bliss'a:  0.5677
# Współczynnik Feret'a:  0.3673
#
#
# Srodek ciezkosci:  [160.43, 318.21]
# Współczynnik Blair-Bliss'a:  0.9965
# Współczynnik Feret'a:  0.95
#
#
# Srodek ciezkosci:  [203.89, 177.71]
# Współczynnik Blair-Bliss'a:  0.9969
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [230.97, 283.37]
# Współczynnik Blair-Bliss'a:  0.9967
# Współczynnik Feret'a:  1.0526
#
#
# Srodek ciezkosci:  [231.62, 326.88]
# Współczynnik Blair-Bliss'a:  0.9955
# Współczynnik Feret'a:  1.05
#
#
#
#
#
# Ilosc obiektów na zdjęciu 18: 17
# Obiekty zajmuja: 7.56% obszaru zdjęcia
# Srodek ciezkosci:  [43.38, 222.53]
# Współczynnik Blair-Bliss'a:  0.9938
# Współczynnik Feret'a:  1.0667
#
#
# Srodek ciezkosci:  [72.04, 303.54]
# Współczynnik Blair-Bliss'a:  0.9957
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [75.51, 224.09]
# Współczynnik Blair-Bliss'a:  0.9949
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [86.07, 357.85]
# Współczynnik Blair-Bliss'a:  0.9939
# Współczynnik Feret'a:  0.9444
#
#
# Srodek ciezkosci:  [91.95, 276.47]
# Współczynnik Blair-Bliss'a:  0.9953
# Współczynnik Feret'a:  1.0667
#
#
# Srodek ciezkosci:  [110.93, 300.61]
# Współczynnik Blair-Bliss'a:  0.9921
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [125.9, 243.74]
# Współczynnik Blair-Bliss'a:  0.9894
# Współczynnik Feret'a:  1.0667
#
#
# Srodek ciezkosci:  [129.37, 279.96]
# Współczynnik Blair-Bliss'a:  0.9913
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [139.11, 340.78]
# Współczynnik Blair-Bliss'a:  0.9961
# Współczynnik Feret'a:  0.9412
#
#
# Srodek ciezkosci:  [150.32, 179.13]
# Współczynnik Blair-Bliss'a:  0.9971
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [151.23, 254.67]
# Współczynnik Blair-Bliss'a:  0.9927
# Współczynnik Feret'a:  1.0667
#
#
# Srodek ciezkosci:  [183.62, 323.7]
# Współczynnik Blair-Bliss'a:  0.9948
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [190.13, 236.81]
# Współczynnik Blair-Bliss'a:  0.9938
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [197.17, 282.57]
# Współczynnik Blair-Bliss'a:  0.9947
# Współczynnik Feret'a:  1.0
#
#
# Srodek ciezkosci:  [221.69, 194.59]
# Współczynnik Blair-Bliss'a:  0.9954
# Współczynnik Feret'a:  1.0667
#
#
# Srodek ciezkosci:  [247.5, 291.77]
# Współczynnik Blair-Bliss'a:  0.9951
# Współczynnik Feret'a:  1.0625
#
#
# Srodek ciezkosci:  [248.47, 331.42]
# Współczynnik Blair-Bliss'a:  0.9935
# Współczynnik Feret'a:  1.0
